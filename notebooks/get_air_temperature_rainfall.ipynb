# %% [markdown]
# # Exploration of Data.gov.sg's weather and rainfall API
#
# Ref: https://beta.data.gov.sg/collections/1459/view
#
# Data of interest: Realtime air temperature and rainfall.
# From a sample response of realtime air temperature, it was noted that there are only 3 sensors that detects the air temperature, whereas for rainfall, there are 64 of such.

# %%
# Library imports
from random import randint
from typing import Union, Dict
import requests
import numpy as np

# %% [markdown]
# ### Helper functions

# %%
def api_query(api_link: str,  agent_id: str) -> Union[Dict,None]:
    """Function which executes query via an api link using a provided agent_id as an identifier to avoid rejection of query request

    Args:
        api_link (str): API Link which requests is to be made
        agent_id (str): Id used for request header

    Returns:
        Dictioanry containing request content. None when exception are encountered.
    """
    req_headers = {"User-agent": agent_id}
    try:
        res = requests.get(api_link,
                            headers=req_headers,
                            timeout=5)
        # Raise if HTTPError occured
        res.raise_for_status()

        # Check the status code before extending the number of posts
        if res.status_code == 200:
            print(f"Request sucessful with {res.status_code}")
            the_json = res.json()
        return the_json

    except requests.exceptions.HTTPError as errh:
        print(errh)
    except requests.exceptions.ConnectionError as errc:
        print(errc)
    except requests.exceptions.Timeout as errt:
        print(errt)
    except requests.exceptions.RequestException as err:
        print(err)
    return None

def query_average_air_temperature(api_link: str = "https://api.data.gov.sg/v1/environment/air-temperature", agent_id: str= "test_qzq"): 
    air_temp_response = api_query(api_link=api_link, agent_id=agent_id)
    if not air_temp_response:
        print("No response received")
        return {}
    else:
        station_temp_readings_list = air_temp_response["items"][0]["readings"]
        print(f"Number of air temperature sensor stations: {len(station_temp_readings_list)}")
        actual_readings = [readings_dict["value"] for readings_dict in station_temp_readings_list]
        
        min_reading, max_reading = np.min(actual_readings), np.max(actual_readings)
    return min_reading, max_reading



def query_average_rainfall(api_link: str = "https://api.data.gov.sg/v1/environment/rainfall", agent_id: str= "test_qzq"): 
    new_rainfall_dict = {}
    rainfall_response = api_query(api_link=api_link, agent_id=agent_id)
    if not rainfall_response:
        print("No response received")
        return new_rainfall_dict
    else:
        stations_list = rainfall_response["metadata"]["stations"]
        print(f"Number of rainfall stations: {len(stations_list)}")
        readings = rainfall_response["items"][0]["readings"]
        for station_dict, reading_dict in zip(stations_list, readings):
            # Pop name key from statiio
            name = station_dict.pop("name")
            location = station_dict.pop("location")
            lat, lon = location["latitude"], location["longitude"]
            value = reading_dict["value"]
            if name not in new_rainfall_dict:
                new_rainfall_dict[name] = station_dict
                new_rainfall_dict[name]["latitude"] = lat
                new_rainfall_dict[name]["longitude"] = lon
                new_rainfall_dict[name]["value"] = value
            # Update the value
            else:
                new_rainfall_dict[name]["value"] = value            
    return new_rainfall_dict

# %% [markdown]
# ### Function call to explore response outputs

# %%
query_average_air_temperature()
# Out:
# Request sucessful with 200
# Number of air temperature sensor stations: 3
# (25.6, 27.0)

# %%
query_average_rainfall()
# Out:
# Request sucessful with 200
# Number of rainfall stations: 64
# {'Alexandra Road': {'id': 'S77',
#   'device_id': 'S77',
#   'latitude': 1.2937,
#   'longitude': 103.8125,
#   'value': 0},
#  'Ang Mo Kio Avenue 5': {'id': 'S109',
#   'device_id': 'S109',
#   'latitude': 1.3764,
#   'longitude': 103.8492,
#   'value': 0},
#  'Banyan Road': {'id': 'S117',
#   'device_id': 'S117',
#   'latitude': 1.256,
#   'longitude': 103.679,
#   'value': 0},
#  'Bukit Panjang Road': {'id': 'S64',
#   'device_id': 'S64',
#   'latitude': 1.3824,
#   'longitude': 103.7603,
#   'value': 0},
#  'Bukit Timah Road': {'id': 'S90',
#   'device_id': 'S90',
#   'latitude': 1.3191,
#   'longitude': 103.8191,
#   'value': 0},
#  'Choa Chu Kang Avenue 4': {'id': 'S114',
#   'device_id': 'S114',
#   'latitude': 1.38,
#   'longitude': 103.73,
#   'value': 0},
#  'Clementi Road': {'id': 'S50',
#   'device_id': 'S50',
#   'latitude': 1.3337,
#   'longitude': 103.7768,
#   'value': 0},
#  'East Coast Parkway': {'id': 'S107',
#   'device_id': 'S107',
#   'latitude': 1.3135,
#   'longitude': 103.9625,
#   'value': 0},
#  'GEYLANG EAST CENTRAL': {'id': 'S215',
#   'device_id': 'S215',
#   'latitude': 1.32785,
#   'longitude': 103.88899,
#   'value': 0},
#  'Handy Road': {'id': 'S118',
#   'device_id': 'S118',
#   'latitude': 1.2994,
#   'longitude': 103.8461,
#   'value': 0},
#  'Holland Road': {'id': 'S120',
#   'device_id': 'S120',
#   'latitude': 1.30874,
#   'longitude': 103.818,
#   'value': 0},
#  'Jurong Pier Road': {'id': 'S33',
#   'device_id': 'S33',
#   'latitude': 1.3081,
#   'longitude': 103.71,
#   'value': 0},
#  'Kent Ridge Road': {'id': 'S71',
#   'device_id': 'S71',
#   'latitude': 1.2923,
#   'longitude': 103.7815,
#   'value': 0},
#  'Kim Chuan Road': {'id': 'S43',
#   'device_id': 'S43',
#   'latitude': 1.3399,
#   'longitude': 103.8878,
#   'value': 0},
#  'Kranji Way': {'id': 'S66',
#   'device_id': 'S66',
#   'latitude': 1.4387,
#   'longitude': 103.7363,
#   'value': 0},
#  'Lim Chu Kang Road': {'id': 'S112',
#   'device_id': 'S112',
#   'latitude': 1.43854,
#   'longitude': 103.70131,
#   'value': 0},
#  'Lornie Road': {'id': 'S07',
#   'device_id': 'S07',
#   'latitude': 1.3415,
#   'longitude': 103.8334,
#   'value': 0},
#  'Mandai Lake Road': {'id': 'S40',
#   'device_id': 'S40',
#   'latitude': 1.4044,
#   'longitude': 103.78962,
#   'value': 0},
#  'Marine Parade Road': {'id': 'S113',
#   'device_id': 'S113',
#   'latitude': 1.30648,
#   'longitude': 103.9104,
#   'value': 0},
#  'Nanyang Avenue': {'id': 'S44',
#   'device_id': 'S44',
#   'latitude': 1.34583,
#   'longitude': 103.68166,
#   'value': 0},
#  'Nicoll Highway': {'id': 'S119',
#   'device_id': 'S119',
#   'latitude': 1.30105,
#   'longitude': 103.8666,
#   'value': 0},
#  'Old Choa Chu Kang Road': {'id': 'S121',
#   'device_id': 'S121',
#   'latitude': 1.37288,
#   'longitude': 103.72244,
#   'value': 0},
#  'Old Toh Tuck Road': {'id': 'S35',
#   'device_id': 'S35',
#   'latitude': 1.3329,
#   'longitude': 103.7556,
#   'value': 0},
#  'Pasir Ris Street 51': {'id': 'S94',
#   'device_id': 'S94',
#   'latitude': 1.3662,
#   'longitude': 103.9528,
#   'value': 0},
#  'Poole Road': {'id': 'S78',
#   'device_id': 'S78',
#   'latitude': 1.30703,
#   'longitude': 103.89067,
#   'value': 0},
#  'Punggol Central': {'id': 'S81',
#   'device_id': 'S81',
#   'latitude': 1.4029,
#   'longitude': 103.9092,
#   'value': 0},
#  'S201': {'id': 'S201',
#   'device_id': 'S201',
#   'latitude': 1.32311,
#   'longitude': 103.76714,
#   'value': 0},
#  'S203': {'id': 'S203',
#   'device_id': 'S203',
#   'latitude': 1.29164,
#   'longitude': 103.7702,
#   'value': 0},
#  'S207': {'id': 'S207',
#   'device_id': 'S207',
#   'latitude': 1.32485,
#   'longitude': 103.95836,
#   'value': 0},
#  'S208': {'id': 'S208',
#   'device_id': 'S208',
#   'latitude': 1.3136,
#   'longitude': 104.00317,
#   'value': 0},
#  'S209': {'id': 'S209',
#   'device_id': 'S209',
#   'latitude': 1.42111,
#   'longitude': 103.84472,
#   'value': 0},
#  'S210': {'id': 'S210',
#   'device_id': 'S210',
#   'latitude': 1.44003,
#   'longitude': 103.76904,
#   'value': 0},
#  'S211': {'id': 'S211',
#   'device_id': 'S211',
#   'latitude': 1.42918,
#   'longitude': 103.75711,
#   'value': 0},
#  'S212': {'id': 'S212',
#   'device_id': 'S212',
#   'latitude': 1.31835,
#   'longitude': 103.93574,
#   'value': 0},
#  'S213': {'id': 'S213',
#   'device_id': 'S213',
#   'latitude': 1.32427,
#   'longitude': 103.8097,
#   'value': 0},
#  'S214': {'id': 'S214',
#   'device_id': 'S214',
#   'latitude': 1.29911,
#   'longitude': 103.88289,
#   'value': 0},
#  'S216': {'id': 'S216',
#   'device_id': 'S216',
#   'latitude': 1.36019,
#   'longitude': 103.85335,
#   'value': 0},
#  'S217': {'id': 'S217',
#   'device_id': 'S217',
#   'latitude': 1.35041,
#   'longitude': 103.85526,
#   'value': 0},
#  'S218': {'id': 'S218',
#   'device_id': 'S218',
#   'latitude': 1.36491,
#   'longitude': 103.75065,
#   'value': 0},
#  'S219': {'id': 'S219',
#   'device_id': 'S219',
#   'latitude': 1.37999,
#   'longitude': 103.87643,
#   'value': 0},
#  'S220': {'id': 'S220',
#   'device_id': 'S220',
#   'latitude': 1.38666,
#   'longitude': 103.89797,
#   'value': 0},
#  'S221': {'id': 'S221',
#   'device_id': 'S221',
#   'latitude': 1.35691,
#   'longitude': 103.89088,
#   'value': 0},
#  'S222': {'id': 'S222',
#   'device_id': 'S222',
#   'latitude': 1.28987,
#   'longitude': 103.82364,
#   'value': 0},
#  'S223': {'id': 'S223',
#   'device_id': 'S223',
#   'latitude': 1.29984,
#   'longitude': 103.80264,
#   'value': 0},
#  'S224': {'id': 'S224',
#   'device_id': 'S224',
#   'latitude': 1.34392,
#   'longitude': 103.98409,
#   'value': 0},
#  'S226': {'id': 'S226',
#   'device_id': 'S226',
#   'latitude': 1.27472,
#   'longitude': 103.80389,
#   'value': 0},
#  'S227': {'id': 'S227',
#   'device_id': 'S227',
#   'latitude': 1.43944,
#   'longitude': 103.80389,
#   'value': 0},
#  'S228': {'id': 'S228',
#   'device_id': 'S228',
#   'latitude': 1.34703,
#   'longitude': 103.70073,
#   'value': 0},
#  'S229': {'id': 'S229',
#   'device_id': 'S229',
#   'latitude': 1.35167,
#   'longitude': 103.72195,
#   'value': 0},
#  'S230': {'id': 'S230',
#   'device_id': 'S230',
#   'latitude': 1.30167,
#   'longitude': 103.76444,
#   'value': 0},
#  'Scotts Road': {'id': 'S111',
#   'device_id': 'S111',
#   'latitude': 1.31055,
#   'longitude': 103.8365,
#   'value': 0},
#  'Seletar Aerospace View': {'id': 'S900',
#   'device_id': 'S900',
#   'latitude': 1.41284,
#   'longitude': 103.86922,
#   'value': 0},
#  'Sentosa': {'id': 'S60',
#   'device_id': 'S60',
#   'latitude': 1.25,
#   'longitude': 103.8279,
#   'value': 0},
#  'Simei Avenue': {'id': 'S84',
#   'device_id': 'S84',
#   'latitude': 1.3437,
#   'longitude': 103.9444,
#   'value': 0},
#  'Somerset Road': {'id': 'S79',
#   'device_id': 'S79',
#   'latitude': 1.3004,
#   'longitude': 103.8372,
#   'value': 0},
#  'Toa Payoh North': {'id': 'S88',
#   'device_id': 'S88',
#   'latitude': 1.3427,
#   'longitude': 103.8482,
#   'value': 0},
#  'Towner Road': {'id': 'S123',
#   'device_id': 'S123',
#   'latitude': 1.3214,
#   'longitude': 103.8577,
#   'value': 0},
#  'Tuas Road': {'id': 'S89',
#   'device_id': 'S89',
#   'latitude': 1.31985,
#   'longitude': 103.66162,
#   'value': 0},
#  'Tuas South Avenue 3': {'id': 'S115',
#   'device_id': 'S115',
#   'latitude': 1.29377,
#   'longitude': 103.61843,
#   'value': 0},
#  'Upper Changi Road North': {'id': 'S24',
#   'device_id': 'S24',
#   'latitude': 1.3678,
#   'longitude': 103.9826,
#   'value': 0},
#  'Upper Peirce Reservoir Park': {'id': 'S69',
#   'device_id': 'S69',
#   'latitude': 1.37,
#   'longitude': 103.805,
#   'value': 0},
#  'Upper Thomson Road': {'id': 'S08',
#   'device_id': 'S08',
#   'latitude': 1.3701,
#   'longitude': 103.8271,
#   'value': 0},
#  'West Coast Highway': {'id': 'S116',
#   'device_id': 'S116',
#   'latitude': 1.281,
#   'longitude': 103.754,
#   'value': 0},
#  'Woodlands Avenue 9': {'id': 'S104',
#   'device_id': 'S104',
#   'latitude': 1.44387,
#   'longitude': 103.78538,
#   'value': 0}}
